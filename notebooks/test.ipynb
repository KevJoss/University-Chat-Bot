# %%
import os
import pandas as pd
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings
from langchain_core.documents import Document

# %%
data_service = pd.read_csv(CSV_PATH)

data_service
# Out:
#                                              Servicio  \
# 0                              Catálogo Bibliográfico
# 1     Reserva o renovación de recursos de biblioteca
# 2                          Uso de espacios de estudio
# 3    Seguimiento Académico, laboral y de salud mental
# 4                                     Atención médica
# 5                Orientación Vocacional y Profesional
# 6                                Atención Psicológica
# 7         Uso de\n  espacios deportivos y recreativos
# 8                                   Ayudas Económicas
# 9                                               Becas
# 10                Gestión de Residencia Universitaria
# 11  Servicios de Asesoramiento para Movilidad Estu...
# 12                        Pruebas de Ubicación Inglés
# 13                      Soporte Servicios Académicos
# 14                   Autorización Terceras Matrículas
# 15  Retiros de Estudiantes de Carrera de Tercer Ni...
# ...
